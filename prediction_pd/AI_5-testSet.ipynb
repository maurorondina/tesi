# %% [markdown]
# ## Test Set

# %%
import pandas as pd
import numpy as np
import re
import pickle

# %%
def initial_text_cleaning(text):
    text = text.lower()                                             # transform to lowercase
    text = re.sub(r'\n', '', text)                                  # remove \n
    text = re.sub(r'(\(|\[|\{)[^(\)|\]|\})]*(\)|\]|\})', '', text)  # remove everything in parentheses
    text = re.sub(r'http(s)?:\/\/\S+', '', text)                    # remove url
    text = re.sub(r'[^a-z\s]', '', text)  #[^\w\s]                  # remove everything that is not a word (therefore also numbers and punctuation)
    text = re.sub(r'\b\w\b', '', text)                              # remove all single letters
    text = re.sub(r'\s{2,}', ' ', text).strip()                     # reformat spaces
    return text


# cleaning text of stop words
from nltk.corpus import stopwords

def remove_stopwords(text, stopwords):
    words = text.split()
    return ' '.join([w for w in words if w not in stopwords])

# cleaning text of nonsense words
from nltk.corpus import words
words_dictionary = set(words.words())
def remove_nonsensewords(text):
    words = text.split()
    return ' '.join([w for w in words if w in words_dictionary])


# stemming and lemmatization
from nltk.stem.porter import PorterStemmer
porter = PorterStemmer()
def stemming(text):
    words = text.split()
    return ' '.join([porter.stem(w) for w in words])

from nltk.stem.wordnet import WordNetLemmatizer
wordnet = WordNetLemmatizer()
def lemmatization(text):
    words = text.split()
    return ' '.join([wordnet.lemmatize(w) for w in words])

# %%
## create and save test set
#testset_list = "/Users/maurorondina/Desktop/Tesi - Magistrale/data/testset_list.txt"
#paper_line_list = []
#with open(testset_list, 'r') as in_file:
#    paper_line_list = in_file.readlines()
#
#data_dir = "/Users/maurorondina/Desktop/Tesi - Magistrale/data/papers"  # data/prova data/papers
#df_test = pd.DataFrame(columns=["id_subsection", "paragraph_name", "text_subsection", "label_subsection"])
#for paper_line in paper_line_list:
#    info_paper = paper_line.split("\t\t")
#    path_dir = os.path.join(data_dir, "paper_" + info_paper[0])
#    if os.path.isdir(path_dir):
#        ##analyzable_test_paper_path = os.path.join(path_dir, "paper_" + info_paper[0] + "_analyzable_test.xml")
#        analyzable_paper_path = os.path.join(path_dir, "paper_" + info_paper[0] + "_analyzable.xml")
#        ##if os.path.exists(analyzable_test_paper_path) and os.path.exists(analyzable_paper_path):
#        if os.path.exists(analyzable_paper_path):
#            # 1- parse xml
#            ##tree = ET.parse(analyzable_test_paper_path)
#            tree = ET.parse(analyzable_paper_path)
#            root = tree.getroot()
#            # 2- get all subsections
#            found_subsections = root.findall('.//subsection')
#            for subsection in found_subsections:
#                if '.-1.' in subsection.attrib['id']:
#                    continue
#                else:
#                    paragraph_id = subsection.attrib['id'][:subsection.attrib['id'].rfind('.')]
#                    paragraph = root.find("./paragraph[@id='" + paragraph_id + "']")
#                    if paragraph is None or 'reference' in paragraph.attrib['name'].lower():
#                        continue
#                    # add to dataset
#                    df_test = df_test.append({"id_subsection": subsection.attrib['id'],
#                                            "paragraph_name": paragraph.attrib['name'],
#                                            "text_subsection": subsection.text,
#                                            "label_subsection": np.nan
#                                            }, ignore_index=True)
##print(df_test)
#dataset_path = "/Users/maurorondina/Desktop/Tesi - Magistrale/data/test_set.pkl"  # data/prova data/papers
#df_test.to_pickle(dataset_path)  # to save it


## load test set
dataset_path = "/Users/maurorondina/Desktop/Tesi - Magistrale/data/test_set.pkl"
df_test = pd.read_pickle(dataset_path)   # to read it

df_test = df_test.dropna(subset=['text_subsection'])

# text - cleaning:
df_test['text_subsection'] = df_test['text_subsection'].apply(initial_text_cleaning)

# remove stop-words:
stopwords_file = "/Users/maurorondina/Desktop/Tesi - Magistrale/data/stopwords_list.txt"
stopwords_extended_list = stopwords.words('english')
with open(stopwords_file, 'r') as file:
    stopwords_extended_list.extend([line.replace('\n', '') for line in file.readlines()])
stopwords_extended_list.extend(['table', 'tab', 'figure', 'fig'])
stopwords = set(stopwords_extended_list)
df_test['text_subsection'] = df_test['text_subsection'].apply(lambda x: remove_stopwords(x, stopwords))

# stemming and lemmatization:
df_test['text_subsection'] = df_test['text_subsection'].apply(stemming)
#df_test['text_subsection'] = df_test['text_subsection'].apply(lemmatization)

# remove nonsense-words:
#df_test['text_subsection'] = df_test['text_subsection'].apply(remove_nonsensewords)

# %%
df_test[df_test['text_subsection'].isna()]
# deve essere vuota!
# Out:
# Empty DataFrame
# Columns: [id_subsection, paragraph_name, text_subsection, label_subsection]
# Index: []

# %%
df_test['label_id'] = df_test['label_subsection'].factorize()[0]
df_test
# Out:
#       id_subsection        paragraph_name  \
# 0          2535.1.1              Abstract
# 1          2535.2.1          Introduction
# 2          2535.2.2          Introduction
# 3          2535.2.3          Introduction
# 4          2535.2.4          Introduction
# ...             ...                   ...
# 27114     3050.6.15  Experimental Results
# 27115     3050.6.16  Experimental Results
# 27116     3050.6.17  Experimental Results
# 27117     3050.6.18  Experimental Results
# 27118     3050.6.19  Experimental Results
#
#                                          text_subsection label_subsection  \
# 0      paper address problem track diagnos complex sy...              NaN
# 1      complex sophist current gener industri process...              NaN
# 2      want monitor state system reliabl detect abnor...              NaN
# 3      paper propos differ approach problem model com...              NaN
# 4      express discret failur mode produc discontinuo...              NaN
# ...                                                  ...              ...
# 27114  evolut annular prior input imag thumbnail illu...              NaN
# 27115  discuss demonstr approach spatial organ imag u...              NaN
# 27116  author consid system interleav map posit estim...              NaN
# 27117  believ absenc requir posit prior approach suit...              NaN
# 27118  imag adjac posit impli success map depend imag...              NaN
#
#        label_id
# 0            -1
# 1            -1
# 2            -1
# 3            -1
# 4            -1
# ...         ...
# 27114        -1
# 27115        -1
# 27116        -1
# 27117        -1
# 27118        -1
#
# [27118 rows x 5 columns]

# %%
print("Subsections in test set = %s" % len(df_test.id_subsection))
id_paper_set = set()
df_test.id_subsection.apply(lambda x: id_paper_set.add(x[:x.find('.')]))
print("Valid papers in test set = %s" % len(id_paper_set))
# Out:
# Subsections in test set = 27118
# Valid papers in test set = 405

# %% [markdown]
# Load vectorizer:

# %%
vectorizer_path = "/Users/maurorondina/Desktop/Tesi - Magistrale/data/tdidf_bigr"
with open(vectorizer_path, 'rb') as feature_extractor:
    vectorizer = pickle.load(feature_extractor)

# %%
X_test = vectorizer.transform(df_test['text_subsection'])
X_test.shape
# Out:
# (27118, 40000)

# %% [markdown]
# Load classifier:

# %%
classifier_path = "/Users/maurorondina/Desktop/Tesi - Magistrale/data/tdidf_bigr-lr"
with open(classifier_path, 'rb') as training_model:
    model = pickle.load(training_model)

# %% [markdown]
# Predict Test Set:

# %%
df_test['label_id'] = 1
y_test = df_test['label_id']
print(X_test.shape, y_test.shape)
# Out:
# (27118, 40000) (27118,)

# %%
# %%time
y_pred = model.predict(X_test)
# Out:
# CPU times: user 3.51 ms, sys: 1.78 ms, total: 5.29 ms
# Wall time: 9.01 ms

# %%
print(y_pred, len(y_pred))
print(len([i for i in y_pred if i==1]))
# Out:
# [0 0 0 ... 0 0 0] 27118
# 224

# %% [markdown]
# Results:

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# [[    0     0]
#  [26894   224]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.01      0.02     27118
#
#     accuracy                           0.01     27118
#    macro avg       0.50      0.00      0.01     27118
# weighted avg       1.00      0.01      0.02     27118
#
# 0.008260196179659268
# /usr/local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#vedi anche:
# - https://github.com/susanli2016/Machine-Learning-with-Python/blob/master/Consumer_complaints.ipynb
# - https://stackabuse.com/text-classification-with-python-and-scikit-learn/

# %%
df_test['label_id_predict'] = y_pred
df_test
# Out:
#       id_subsection        paragraph_name  \
# 0          2535.1.1              Abstract
# 1          2535.2.1          Introduction
# 2          2535.2.2          Introduction
# 3          2535.2.3          Introduction
# 4          2535.2.4          Introduction
# ...             ...                   ...
# 27114     3050.6.15  Experimental Results
# 27115     3050.6.16  Experimental Results
# 27116     3050.6.17  Experimental Results
# 27117     3050.6.18  Experimental Results
# 27118     3050.6.19  Experimental Results
#
#                                          text_subsection label_subsection  \
# 0      paper address problem track diagnos complex sy...              NaN
# 1      complex sophist current gener industri process...              NaN
# 2      want monitor state system reliabl detect abnor...              NaN
# 3      paper propos differ approach problem model com...              NaN
# 4      express discret failur mode produc discontinuo...              NaN
# ...                                                  ...              ...
# 27114  evolut annular prior input imag thumbnail illu...              NaN
# 27115  discuss demonstr approach spatial organ imag u...              NaN
# 27116  author consid system interleav map posit estim...              NaN
# 27117  believ absenc requir posit prior approach suit...              NaN
# 27118  imag adjac posit impli success map depend imag...              NaN
#
#        label_id  label_id_predict
# 0             1                 0
# 1             1                 0
# 2             1                 0
# 3             1                 0
# 4             1                 0
# ...         ...               ...
# 27114         1                 0
# 27115         1                 0
# 27116         1                 0
# 27117         1                 0
# 27118         1                 0
#
# [27118 rows x 6 columns]

# %%
df_pd_pred = df_test.loc[df_test['label_id_predict'] == 1]
df_pd_pred
# Out:
#       id_subsection                          paragraph_name  \
# 26        2535.3.18                           The framework
# 258        2539.5.4                 Synthesis of Invariants
# 606        2543.3.9             Anchoring in the literature
# 622       2543.4.14     A computational theory of anchoring
# 631       2543.4.23     A computational theory of anchoring
# ...             ...                                     ...
# 26371      3040.3.3  Preferred Explanations and Relaxations
# 26536      3042.3.8                              Background
# 26537      3042.3.9                              Background
# 26600      3043.3.1               2 Background and Notation
# 26831      3045.5.6                  Integration in CMODELS
#
#                                          text_subsection label_subsection  \
# 26     dbn diagnosi goal repres diagnost system type ...              NaN
# 258    function extend updat preserv weaken describ f...              NaN
# 606    problem connect linguist descript object physi...              NaN
# 622             definit symbol descript set unari predic              NaN
# 631    descript state associ individu symbol descript...              NaN
# ...                                                  ...              ...
# 26371  defin relax problem definit subset relax probl...              NaN
# 26536  qk consist statement node connect direct arc n...              NaN
# 26537  statement node contain individu piec data qk s...              NaN
# 26600  pomdp defin set state set action set observ tr...              NaN
# 26831  cmodel integr impli call aspsat sat solver asp...              NaN
#
#        label_id  label_id_predict
# 26            1                 1
# 258           1                 1
# 606           1                 1
# 622           1                 1
# 631           1                 1
# ...         ...               ...
# 26371         1                 1
# 26536         1                 1
# 26537         1                 1
# 26600         1                 1
# 26831         1                 1
#
# [224 rows x 6 columns]

# %%
for _, row in df_pd_pred.iterrows():
    if len(row['text_subsection'].split(' ')) > 20:
        print(row['id_subsection'] +" :", row['text_subsection'], '\n')
# Out:
# 2535.3.18 : dbn diagnosi goal repres diagnost system type describ dbn turn use tcg system blueprintfor skeleton dbn tcg schema system equat describ continu system dynam distinguish type arc tcg tempor arc annot dt nontempor arc variabl incom tempor arc tcg express instantan constraint function predecessor variabl incom tempor arc tcg express tempor constraint
#
# 2539.5.4 : function extend updat preserv weaken describ follow section algorithm identifi candid invari ground instanc true initi state comput start atom schemata predic pi occur problem instanc xi sequenc distinct variabl algorithm goe stage consid oper stage
#
# 2543.3.9 : problem connect linguist descript object physic refer larg studi philosoph linguist tradit fact borrow term anchor situat semant term denot assign variabl individu relat locat tradit provid sourc inspir conceptu anchor problem typic disregard formal comput aspect necessari turn idea techniqu
#
# 2543.5.5 : term framework symbol system given planner individu symbol denot corridor door predic symbol refer posit width perceptu system extract linear contour consist set sonar measur percept wall individu anchor corridor thick descript segment percept doubl anchor
#
# 2543.5.14 : term formal model symbol system consist planner plan executor code lisp individu denot car predic denot linguist term posit road network
#
# 2543.5.16 : predic ground relat given handcod associ predic set admiss valu correspond attribut instanc predic red associ set admiss hsl valu attribut color symbol descript tupl predic plan executor send sim appropri symbol descript individu symbol anchor instanc executor interest find car small red locat cross send sim list car note milou testb anchor modul anchor object lp sim anchor object explicitli request executor
#
# 2548.3.1 : standard terminolog formal instanc csp tripl consist set variabl set valu collect constraint ccq ci pair tupl relat ariti jtj note loss gener assum constraint involv tupl consolid singl constraint assum tupl variabl occur collect clear instanc view instanc homomorph problem structur ap bp univers ap univers bp relat bp distinct relat occur relat ap defin follow relat occur relat ra ft constraintg call homomorph instanc clear instanc homomorph problem structur aand bcan view csp instanc csp simpli break relat ra aa follow gener constraint ra call csp csp instanc use formal paper advantag
#
# 2548.3.24 : definit instanc abof homomorph problem coher associ csp instanc csp follow properti constraint csp tupl map hab defin partial homomorph ato
#
# 2552.3.1 : specifi knowledg base queri use descript logic dlr basic element dlr concept nari relat assum deal finit set atom relat atom concept constant denot respect use denot arbitrari relat denot arbitrari concept respect built follow syntax denot compon relat integ nmax denot ariti relat integ nmax denot nonneg integ use usual abbrevi particular ctc
#
# 2552.3.4 : semant dlr specifi follow interpret kb constitut interpret domain interpret function assign constant element uniqu name assumpt concept subset ci relat ariti subset ri condit satisfi observ constructor relat express differ relat complement assum subset fix infinit countabl domain simplifi notat distinguish constant interpret
#
# 2552.4.4 : point paper problem come differ form pi ci di ci ri ri ri ci ci ci ri ri di ri ri di semant rule dlr depend variou assumpt accur knowledg object kb pair satisfi view respect knowledg object distinguish close domain assumpt exact set object domain interpret known coincid set object appear kb formal interpret kb satisfi close domain assumpt coincid set object kb
#
# 2552.4.9 : problem answer queri view open domain assumpt dlr follow given kb set view definit def extens ext specif sound complet exact queri ariti tupl object kb decid an decid qi satisfi open domain assumpt model model vm
#
# 2563.3.3 : problem type state detect chang paramet stochast model possibl approach chang detect viewpoint mathemat statist consid instanc sequenc random variabl character condit probabl suppos chang reflect chang paramet vector assum random variabl independ chang occur denot chang time problem chang detect compris differ task detect chang possibl decid point time sequenc observ contain chang estim chang time estim paramet problem formal framework mathemat statist task instanc consid problem hypothes test hypothesi denot paramet time test altern likewis second task approach problem estim paramet note second third task consid auxiliari problem question favor
#
# 2567.3.1 : wish repres possibl histori system compos nondeterminist concurr automata given command issu automata output creat structur allow increment bestfirst enumer possibl trajectori extend formal livingston order compactli repres trajectori add set transit variabl repres nondeterminist transit automaton time step assign transit variabl likelihood repres prior probabl correspond nondeterminist transit occur trajectori system assign transit variabl given appropri independ assumpt set trajectori increment enumer order likelihood order captur feasibl behavior automata introduc set formula describ inputoutput map automata state set formula mt describ feasibl transit automata
#
# 2567.3.2 : definit transit system tupl mt set state variabl repres state automaton denot number automata denot number discret synchron time step state track contain variabl denot set state variabl repres state system time step state variabl rang finit domain denot
#
# 2567.5.2 : vdu vdu cmdin cmdout close flowv zero flowv zero close open zero zero zero zero evolut vduvalv system consid problem determin state physic process model transit system point trajectori sm subset depend variabl assign correspond measur process refer observ
#
# 2567.5.3 : given assign initi state addit given assign command ct observ ot task choos assign yt ensur consist mt maxim likelihood trajectori given start state set command set observ find sequenc transit state consist state model transit consist transit model mt defin trajectori likelihood pm pn rank definit assumpt likelihood assign yt independ xt common assumpt adequ approxim practic note assumpt effect handl singl failur manifest multipl point system
#
# 2567.6.3 : exampl illustr trajectorytrack problem length model exampl box repres assign command cmdin observ flowv flowv variabl assign problem start state highlight yt assign chosen remain variabl constrain base assign arc repres constraint mt constraint shown yt assum rank rank
#
# 2567.9.2 : variabl ym introduc repres choic system evolut track system increment gener consist assign yt repres consist trajectori note mstep trajectori contain assign appear given potenti larg amount gain time step assign induc assign exampl
#
# 2574.3.24 : essenti ontolog tupl va vocabulari set axiom govern theori terminolog firstord theori set predic symbol ariti set horn claus conveni assum symbol vocabulari ontolog distinct actual shoe separ namespac ontolog assumpt loss gener possibl appli renam append uniqu ontolog identifi symbol discuss build base compon defin ontolog useontolog statement add vocabulari axiom specifi ontolog current ontolog assum name uniqu concern name conflict
#
# 2585.3.2 : exampl agent control variabl ident domain dddd agent want ensur want requir need hold order solv problem convent techniqu need assign prioriti agent move certain constraint agent higher prioriti assum preced case constraint commun respons enforc
#
# 2612.3.2 : iff relat point algebra disjunct basic relat repres set basic relat differ basic relat possibl disjunct relat set basic relat denot set relat denot use shorthand notat certain relat exampl written empti relat denot unsatisfi implicitli assum convers relat instanc set relat convers
#
# 2612.3.4 : definit set point relat class partial order problem instanc sat set variabl set binari constraint form tupl total function call interpret
#
# 2615.3.5 : macfac twostag model similaritybas retriev consist psycholog constraint field applic key insight macfac memori content filter extrem cheap match filter potenti huge set candid follow structur match select hand candid stage extrem cheap match base content vector represent comput structur descript dimens content vector repres number occurr particular predic descript exampl descript statement impli statement content vector content vector normal avoid size bias content vector use cheap matcher product provid estim largest structur match obtain origin structur descript
#
# 2631.2.30 : termin time goal tree modifi repres goal ideolog storytel goal modifi world storytel rhetor goal show case exampl antireligi rationalist possess goal show segment histori
#
# 2635.3.11 : action ground instanc action schema set goal descript goal satisfi state world goal fulli achiev goal descript satisfi goal partial achiev set precondit satisfi state world action execut set effect taken state world action execut
#
# 2635.5.3 : given goal graph end propositionlevel goalgraphconstructor extend goal graph goallevel node repres goal fulli partial achiev time step node propositionlevel satisfi goal descript descript edg connect proposit node goal node goal graph call process goal expans
#
# 2655.4.10 : enumer discret binari csp assign valu variabl ad constraint kind problem enumer differ exampl deal schedul problem enumer ad preced constraint task problem call constraint decis constraint
#
# 2655.7.1 : classic schedul shop problem set job consist task schedul set machin consid csp interv problem call open shop problem problem oper given job sequenc want time consid build non preemptiv schedul minim makespan problem nphard
#
# 2684.3.4 : key idea bay filter estim probabl densiti state space condit data posterior typic call belief denot belx px jd xdenot state state time denot data start time time mobil robot distinguish type data perceptu data laser rang measur odometri data control carri robot motion denot belx px loss gener assum observ action arriv altern sequenc
#
# 2685.3.1 : give precis definit prefer solut combinatori problem formul constraint satisfact problem constraint satisfact problem consist set variabl set constraint formul constraint consist relat tupl variabl paper simpli suppos set constraint csp given set domain membership constraint form usual introduc separ
#
# 2690.3.3 : denot set item auction denot set agent denot agent valu bundl item assum riskneutr agent quasilinear util money ui price equat optim strategi utilitymaxim
#
# 2695.3.5 : dynam constraint satisfact problem dcsp type variabl activ variabl normal variabl initi subset variabl activ object find assign activ variabl consist constraint variabl addit dcsp specif contain set activ constraint activ constraint form variabl take valu vx variabl yzw activ dcsp problem translat normal csp problem augment domain variabl dummi valu signifi variabl inact modifi constraint specif accordingli
#
# 2698.3.12 : crew schedul problem problem assign crew given set flight gener flight specif fleet type problem sequenc flight assign crew flight assign exactli crew pair subject complic rule difficult express constraint cost direct encod valid pair enumer problem formul set partion problem formul column variabl correspond pair object partit flight set minimum cost pair
#
# 2700.4.2 : problem formul follow given process time pj job common due earli tardi penalti coeffici respect object minim ej tj earli tardi job jj cj denot complet time job jj schedul
#
# 2714.3.1 : paper use follow notat definit denot finit state space denot start state denot goal state denot set successor state denot set predecessor
#
# 2717.3.15 : definit probabilist relat kb variabl form welltyp termin attribut chain dom type denot variabl letter possibl world function map variabl element set possibl world denot simpli
#
# 2717.6.3 : languag extens impact result allow invers statement form inverseof statement mean impli invers statement issu allow creat kb arbitrarili chain depend variabl
#
# 2738.1.9 : complet descript determinist plan formul possibl object gener object take complex combin elementari properti character final state exampl typic object assembl manufactur robot reach state world manufactur item fulli assembl simplifi descript problem add combin fluent liter lose gener suffici consid object type
#
# 2738.1.10 : term plan problem formul follow given set fluent goal set action set rule describ action affect state world find sequenc action execut initi state world true problem plan check given goal sequenc action check goal true execut initi state determinist case plan comput difficult nphard survey baral
#
# 2738.1.24 : summar probabilist uncertainti sensor plan problem take follow form given set fluent set action domain descript initi interv probabl object desir success probabl goal find sequenc action probabl pfre object true execut guarante greater equal
#
# 2738.1.52 : sound algorithm formul precis term definit plan problem mean tupl hfadfpgfffpi finit set element call fluent finit set element call action finit set express type caus ifffm fi fluent liter fluent negat subinterv interv call object
#
# 2763.4.6 : ccompon path compos entir bidirect edg call bidirect path set variabl partit disjoint group assign variabl group connect bidirect path assum partit group sk denot nj set variabl parent variabl sj clearli set nk form partit defin qj nj ivisj pvipai ui
#
# 2764.6.4 : exampl correspond type node exposit node process process overview text descript type particip process detail qualit descript subev locat descript condit descript tempor object function telic descript topic node locat descript locat descript locat origin destin content specif node locat locat makelocationview content specif node correspond view kb view simpli subset slot object instanc slot isbetween associ locat view display view assembl valu slot associ view exampl makelocationview name function comput valu view
#
# 2764.6.7 : display knowledg base content english concept descript defin problem describ valu slot kb form close possibl english expert get structur kb
#
# 2764.7.1 : comprehens solut edit kb support edit kind knowledg classsubclass slot valu constraint slot valu axiom process knowledg previou work gkbeditor direct edit class hierarchi slot slot valu slot constraint focu present work edit axiom edit system describ enabl knowledg entri interest class axiom abstract exampl graphic descript concept technic detail abstract process map direct graph logic form describ primari subject discuss focu iaai graphic aspect tool assum avail modul convert graph logic show graph enter adddelet list analog correspond ask question
#
# 2767.3.4 : node point ti direct graph prior probabl xi xi formal bayesian network bn set variabl xk tupl direct acycl graph encod independ assumpt joint distribut pxipa set cpd
#
# 2772.4.3 : start group axiom involv adopt intent agent discuss axiom involv agent actual action conclud discuss axiom inherit variabl written existenti quantif assum univers quantifi axiom form typic time time axiom character mental state agent state world chang time captur properti agent reason plan action take time
#
# 2774.6.4 : defin fluent formula goal express second requir formal notion sequenc repres stage travers goal final requir say object reach find object state move higher state hurt posit object possibl make
#
# 2778.2.13 : note mean denot utter nonsens domain cours formal mean represent weather ice cream random variabl kind mean model denot ice cream weather statistician warn residu regress structur say linear model summar relationship kind model domain expert introduc third kind mean interpret statement ice cream sale aspect represent interpret domainth expert assign mean coeffici expert represent formal object statement domain call kind mean domain semant function semant emphas interpret represent effect domain expert think
#
# 2778.2.15 : notion mean program learn mean held respons semant classic statist regress analysi particular sophist human perform adequ analys realli understand point agent learn formal semant lieu domain function semant relationship learn formal relationship random variabl denot unknown learner knowledg agent requir translat formal relationship domain function denot learn gener need knowledg bootstrap process exampl denot daili temperatur call consider amount commonsens knowledg assign statement mean affect mean believ artifici agent benefit provid
#
# 2780.1.28 : rule shown indic control compon modifi input follow rule describ done goal modifi input compon find compon control input find gain control goal modifi input compon find compon input find modifi access right comput system abil read modifi data depend obtain access right data model access right gener actual system type object enumer oper perform object type
#
# 2780.1.34 : given framework provid rule describ gain access object goal gain access oper object oper requir capil find process capabl subsum find take control
#
# 2781.5.9 : consid simplifi version model sl behaviour model consist markov chain state sk pij probabl transit state state follow assumpt pkk pii piii assumpt reflect fact state absorb state repres solut given problem instanc sl algorithm sat typic termin solut assumpt state sk reflect boundari captur intuit measur distanc solut model markov chain finit upper bound primari purpos assumpt keep model simpl possibl allow repres differ problem size attract solut
#
# 2785.4.7 : terminolog introduc terminolog abstract framework optim problem assum set problem instanc problem instanc set candid solut assum solut total order function isbett return true iff solut strictli superior function init return initi solut problem move transform appli solut produc solut move defin oper problem element alter element possibl exampl move node rd th posit list shift th th node oper rd element alter rd th function move return set transform oper element solut function alter return set element alter
#
# 2790.3.1 : assum system charg make decis behalf user specif decis scenario decis scenario refer set fix set choic system effect choic known system task take decis maximum expect util respect user util function outcom approxim thereof system littl user util function achiev aim find enabl decis assum system set queri user provid formal assum decis scenario consist finit set possibl decis finit set possibl outcom distribut function prd term prd denot probabl outcom realiz system take decis util function associ util outcom view ndimension vector ith compon ui simpli assum util normal rang conveni expect util decis respect util function eu pdu prdui note eu linear optim decis wrt maximum expect util gener util function known certainti start elicit process follow model uncertainti densiti set possibl util function system decis condit uncertainti expect util reflect defin expect util given densiti follow eu pdupdu use term queri concret interact user provid util function
#
# 2790.3.4 : eu linear eu comput easili expectationof wrt known state uncertainti optim decis maximum expect util eu denot meu valu state assum forc decis meu eu order reduc uncertainti user util function system set queriesq queri associ finit set possibl respons rq common type queri standard gambl wrt outcom si user prefer si gambl outcom occur probabl worst occur probabl
#
# 2801.4.19 : pomdp techniqu calcul optim control action uncertainti control decis base full probabl distribut gener state estim equat pearl case distribut multitud multivalu probabilist state goal variabl robot locat person locat person statu motion goal remind goal user initi goal plausibl state input pomdp factor probabl distribut state uncertainti aris predominantli local modul speech recognit system conjectur consider uncertainti import domain cost mistak repli larg
#
# 2811.3.1 : definit constraint network defin triplet set variabl associ set discretevalu domain set constraint constraint ci pair ri relat ri dsi dsi xj si dj defin subset variabl si call scope ci relat denot compat tupl dsi allow constraint constraint graph constraint network node variabl arc node iff correspond variabl particip constraint solut assign valu variabl xi di constraint violat
#
# 2814.2.7 : explicit represent mdp exponenti number state variabl factor mdp polynomi larg factor follow intuit formal represent piec knowledg larger inform represent descript domain written english singl sheet paper formal represent take megabyt storag space explicit represent exponenti inform descript turn formal descript circuit larg exactli aim factor
#
# 2814.4.1 : assum reader familiar basic complex class np class polynomi hierarchi sequel denot arbitrari class polynomi hierarchi assum input instanc problem string alphabet length string denot
#
# 2814.4.14 : knphard prove follow assum hr hi reduct sat problem pair satisfi hr hi impli nphard tell hard wrt compil class addit properti monoton hold knphard pair hr hi monoton polynomi reduct pair claus liter hold hr hi iff hr hi note second instanc combin typo problem knphard exist polynomi reduct sat prove monoton definit monoton clear appli specif problem
#
# 2817.3.2 : subset xt project note set unari binari constraint unari constraint ci subset di contain permit assign variabl binari constraint cij set pair di dj contain permit simultan assig binari constraint symmetr set variabl affect constraint call scope tupl consist satisfi constraint scope includ xt global consist extend complet consist assign solut consist complet assign find solut csp npcomplet problem task search solut simplifi enforc arc consist identifi global inconsist valu prune
#
# 2817.4.1 : defin ac wcsp definit essenti equival gener definit given formul emphas similar csp case facilit extens aaai ac algorithm csp wcsp loss gener assum exist unari constraint ci variabl defin dummi constraint ci di definit binari wcsp
#
# 2819.5.11 : wrapper site creat theseu agent programmat access data site wrapper oper plan exampl wrapper yahoo weather send request weather particular citi return correspond data
#
# 2824.6.2 : mdp defin tupl finit set state set action reward function ir repres reward obtain state action markovian transit model px repres probabl go state state action assum mdp infinit horizon futur reward discount exponenti discount factor given valu function defin qv px av bellman oper maxa qv
#
# 2830.4.1 : crucial design featur kraken system natur languag interfac primarili nli intend allow user interact system simpl english statement queri requir pars sentenc question gener english paraphras cycl statement furthermor interfac capabl immedi process lexic correspond knowledg enter user exampl user introduc concept clostridiumbotulinumtoxin knowledg base system prompt user suppli natur languag term refer concept
#
# 2830.6.7 : precis suggestor help user place concept appropri level generalityspecif ontolog user enter concept formul basic initi fact suggestor identifi suitabl number possibl gener special suggest concept enter queri user suggest lead accur statement origin enter
#
# 2830.7.8 : suppli basic definit endem relaps fever kraken fulli pars user origin statement cycl formula kraken invok analog develop tool tool select relev statement mountain spot fever user claim similar endem relaps fever allow user modifi statement fit concept describ kraken scan kb fact mountain spot fever relev cycl assert english paraphras gener sentenc present user follow thing diseas mountain spot fever true endem relaps fever ricketsii caus case endem relaps fever peopl typic acquir endem relaps fever bite tick risk mortal peopl afflict endem relaps fever incub period endem relaps fever peopl usual day risk endem relaps fever spread directli peopl peopl user edit statement refer borellia recurrenti bacterium caus fever second statement true endem relaps fever tickborn user mortal rate incub period infect select statement final statement correct user submit edit assert process salient descriptor tool activ prompt user give fact diseas state yesno question follow sentenc true endem relaps fever distinct stage
#
# 2835.1.3 : thesi propos distribut constraint optim problem consist variabl assign agent valu variabl taken finit discret domain dn respect agent assign variabl control valu knowledg domain object choos valu variabl criterion function possibl assign extremum gener optim problem imagin arbitrarili complex criterion function work restrict function decompos sum set binari function pair variabl xi xj given cost function fij di dj
#
# 2835.1.5 : pair variabl defici optim object find complet assign valu variabl total defici minim formal complet assign valu variabl wish find arg minac xixj fij xi di xj dj gener distribut resourc alloc problem consist set agent perform set oper set weight task complet order complet task requir subset agent perform necessari oper defin task oper agent perform order complet problem solv alloc oper task task perform resourc limit sum perform task maxim formal distribut resourc alloc problem structur ag ag set agent ag
#
# 2836.4.4 : automata memoryless consid markov process associ control action state transit cost transit transit probabl allow deriv markov decis process mdp defin tupl xs finit set state system track set command ea finit set action ft state transit model environ function map xs ea discret probabl distribut xs action nondeterminist write ft probabl transit occur given state cost action use modelbas reason limit diagnosi concern
#
# 2840.3.5 : exampl abl measur rang bear landmark rel local coordin frame measur time denot zt robot sens landmark time follow commonplac notat assum sensor measur correspond exactli landmark convent sole mathemat conveni pose restrict multipl landmark sight singl time step process sequenti
#
# 2846.3.4 : problem contain ident object case appli artifici mark object help differenti object model problem csp assum problem object appropri mark necessari talk map
#
# 2846.3.8 : csp model problem pair proper viewpoint set constraint note definit allow constraint set variabl ci cj sig sig project compound assign
#
# 2857.2.1 : paper consid combinatori problem weakli constrain lack clear global optim object realworld problem characterist exampl configur design diagnosi tempor reason schedul exampl configur vacat advis system choos vacat destin potenti larg catalog given user requir compat constraint differ destin global resourc constraint usual leav larg set possibl solut spite solut discard interest solut possibl prefer differ choic criteria adequ character interest solut
#
# 2857.3.2 : prefer criteria paper consid combinatori problem decis variabl criteria constraint decis variabl xi domain valu chosen exampl xi repres vacat destin ith week constraint form constraint symbol associ relat rc exampl compat constraint requir criterion zi definit form function constraint zi fi domain exampl criteria price qualiti distanc price sum element constraint price price total qualiti defin minimum individu qualiti total distanc maximum individu distanc individu price qualiti destin given tabl catalog
#
# 2861.6.4 : observ interpret respect domain descript domain descript defin transit function character state reach action execut state narr consist domain descript set observ defin possibl histori system character done function map time point action sequenc sequenc finit trajectori form sn sn state action si model narr interpret satisfi fact minim unobserv action occurr formal definit given narr consist model inconsist model narr write
#
# 2864.4.5 : case problem plan uncertainti partial feedback problem nondeterminist belief space problem plan uncertainti full state feedback problem nondeterminist state space case solut action sequenc polici polici map belief state action case polici map world state action second furthermor optim polici minim worst possibl cost goal pure nondeterminist formul expect cost goal probabilist formul worst possibl cost infinit notion success pure nondeterminist plan propos notion strong cyclic plan
#
# 2868.3.3 : sat sat problem special case csp variabl take valu liter variabl complement liter true assum valu fals claus disjunct liter true liter true simplic assum liter appear claus liter negat appear claus satisfi problem consist finit set claus denot complement liter liter set
#
# 2872.3.2 : markov decis process assum fullyobservablemdp finit set state action transit function pr reward function discount infinitehorizon optim criterion discountfactor pr denot probabilitywith system transit state action taken state denot immedi util action state stationari polici determin particular cours action valu polici state expect sum futur discount reward infinit horizon rt
#
# 2872.4.6 : illustr consid resourc alloc problem potenti task tn activ inact chang statu stochast resourc appli point time achiev activ task statu resourc denot variabl sj determin effect resourc complet assign task statu resourc evolv stochast depend use time step multipl resourc appli task size action space dbn illustr depend problem illustr final assum reward ri associ success complet activ task ti
#
# 2874.3.3 : problem tupl set state transit relat defin graph iff exist transit lead initi state set goal state solut problem path sn sn assum state encod bit vector bdd repres characterist function set state transit relat clear consid simpl problem shown state repres bit vector element initi state repres bdd express similarli encod transit relat need refer current state variabl state variabl adopt usual notat bdd literatur prime variabl state
#
# 2876.1.1 : paper present framework justifi agent goaldirect behavior absenc provabl correct plan prior plan system reli complet causal model circumv frame problem implicitli assum unspecifi relationship exist action world approach domain model provid explicit statement action incomplet specifi agent minim depend implicit assumpt select action sequenc achiev goal
#
# 2876.3.1 : assum tradit plan represent assum plan domain exist set complet correct action descript refer dtrue set action descript planner subset dtrue
#
# 2876.3.7 : repres incomplet action descript present languag supplement statement complet action descript approach follow use local closedworld statement overcom incomplet state set lcw statement express limit knowledg state file exist particular directori known softwar agent
#
# 2876.3.8 : work lcw statement express limit complet action descript statement defin term predic doesnotrelyon doesnotmaketru doesnotmakefals truth valu predic directli specifi user infer perform
#
# 2876.3.10 : statement doesnotmaketru assert effect dtrue liter statement doesnotmakefals assert effect dtrue defin completeeffect shorthand formula xx effect doesnotmaketru doesnotmakefals equival explicitli state complet effect assumpt valid
#
# 2876.3.11 : set potenti lcw statement warrant special consider action maintain list precondit possibl list effect domain doesnotmakefals safe assum true implement option automat add frame axiom userspecifi lcw statement plan select plan select problem tupl goal set candid plan describ initi state potenti incomplet action model set local close world statement ideal solut problem find plan achiev goal given actual action descript precis object find ci achiev
#
# 2876.4.28 : list varieti polici prefer plan polici take candid plan return true prefer use risk shorthand findrisk assum plan achiev goal given action descript prefer plan assum achiev goal given
#
# 2879.3.2 : markov decis process option markov decis process model finit discret synchron control process noisi control action formal mdp specifi compon state space cardin set primit action transit function reward function agent act mdp time step locat singl state
#
# 2879.3.9 : domain descript work motiv navig problem aris mobil robot domain take exampl simpl packag deliveri problem agent navig build stochast movement command attempt deliv packag fix locat encod robot state state variabl denot physic locat world indic bit bk record deliveri statu packag goal agent attain state packag deliv fewest step possibl robot primit action correspond movement cardin direc technic flat pure markov option
#
# 2879.3.15 : reward function encod notion goal robot consid simplest possibl reward function reward agent success complet entir task wish minim total number step taken model infinitehorizon undiscount model reward valu function iff bi state final deliveri neg model optim valu function finit extens priorit goal difficult yield complex determinist optim problem minimum latenc path problem discuss case fulli extend version paper
#
# 2879.4.6 : aaai plan episod present set packag deliv repres configur packag deliveri bit bi start state construct determinist graph approxim assumpt macro reach nomin goal oi termin loc take exactli expect durat formal loc bi episod descript loc dj loc locat start state given start state minim tour basi implicit polici episod find cours nphard effect practic heurist method approxim system hundr thousand node second
#
# 2883.3.1 : assum standard proposit languag letter xn set xi take valu negat atom denot xi opposit liter furthermor use set liter set lit
#
# 2887.1.1 : aim paper introduc gener framework preferencebas state space graph focu prefer solut introduc formal definit preferencebas problem introduc pba algorithm gener algorithm design process quasitransit prefer relat defin set solut consid particular subclass prefer structur character axiom call weak preaddit monoton establish termin complet admiss result pba show previou gener particular instanc pba interest algorithm illustr preferencebas web access problem
#
# 2887.2.4 : ci site reliabl ri site probabl pi given site access time ti site problem determin subset site choos launch multipl queri assum resourc bound time money respect restrict subset verifi follow constraint ci assum pair feasibl solut prefer term reliabl rich respect repres relat introduc prefer term reliabl ls ls ls ls min ls sublist contain greatest valu sort decreas order definit aim favor subset includ site high reliabl principl repres maximum oper lexicograph comparison rule refin known leximax detail introduc prefer term rich quantiti repres probabl failur multipl queri character assumpt success sourc independ success failur sourc
#
# 2887.2.7 : imagin variou reformul problem preferredpath problem state space graph exampl consid graph node repres possibl decis concern subset type si formal node character vector repres state decis concern site compon bk boolean true site select si start node correspond initi state decis graph node type successor fail satisfi constraint goal feasibl node type clearli find prefer path node
#
# 2887.4.2 : denot set path link node sourc graph subset goal node denot set path goal node set path link call solutionpath path goal node assum valuat function segment link xp multiset valuat arc assum reflex quasitransit prefer relat defin notic consid finit multiset
#
# 2887.4.5 : denot set maxim path set call multivalu multiset valuat introduc main issu paper preferencebas problem consid finit state space graph graph contain finit number arc finit number nonisol vertic assum exist path finit length number arc denot goal node goal determin entir set mxp
#
# 2890.3.10 : definit set possibl nari tupl element call combin rank definit combin rank feasibl item alloc formal combin rank feasibl correspond collect bc bundl partit subset feasibl combin determin alloc xc xi bc seller keep item set bc denot ith element tupl
#
# 2891.2.3 : assum known cost function specifi tradeoff learn time tag cost optim schedul minim cost exampl mar mission water known sourc water opposit direct robot sent sourc goal water fast possibl minim amount fuel given tradeoff cost fuel copyright american associ artifici intellig right reserv
#
# 2891.4.7 : assum system random process correspond distribut function fn goal predic gn defin schedul system set binari function ith process activ idl refer scheme suspendresum schedul
#
# 2896.4.2 : applic goal specifi reaction failur instanc main goal mobil robot continu deliv object given room imposs robot give recov failur deliv current object room consid instanc goal doreach dep
#
# 2896.4.10 : notat path order use denot infinit path denot finit path execut structur repres rst state path state path write state appear repres path obtain concaten concaten defin rst write prefix path usual write final given set finit path defin set minim path follow
#
# 2898.3.8 : gener term domain dc repres set detector gener set termin symbol vt conveni likelihood detect event likelihood gener termin symbol xi correspond detector di given pd defin case case basi process activ sequenc domain use dc gener symbol string xx xl length
#
# 2899.3.1 : assum agent environ model pomdp arbitrari underli mdp finit observ set environ emit observ agent choos action finit set determinist reactiv polici function map agent task learn determinist reactiv polici base experi gather pomdp consid episod task startstat distribut termin state assum episod termin probabl polici denot trajectori pomdp ot observ correspond termin state assum polici gener welldefin probabl measur set possibl trajectori probabl measur depend startstat distribut pomdp underli mdp suppress notat constant rt denot discount return trajectori discount factor defin valu expect discount return assum welldefin write polici valu briefli
#
# 2901.2.4 : resourc access autom agent essenti mean understood agent ontolog play pivot role provid sourc share precis defin term metadata ontolog typic consist hierarch descript import concept domain descript properti concept degre formal employ captur descript quit variabl rang natur languag logic formal increas formal regular clearli facilit machin understand
#
# 2907.3.2 : problem hsp solv stripsstyl plan problem ground oper stripsstyl plan problem consist set proposit describ state oper set ground oper start state partial specifi goal
#
# 2908.2.1 : staff schedul follow classic oper problem given set employe assign schedul work need ensur certain constraint maintain simplest variat problem known npcomplet
#
# 2908.3.1 : consum call softwar vendor technic support call credit card compani bill inquiri call rout inbound call center larg central pool train agent qualifi address custom inquiri agent handl call busi custom call wait queue agent natur wait time result frustrat dissatisfi custom import call center staf wait time experienc custom accept time busi wish avoid overstaf order minim cost oper call center maxim busi profit
#
# 2908.3.5 : intern corpor call center central custom servic organ serv foci custom contact busi larg industri outsourc call center busi regularli outsourc note central refer organiz central call center frequent geograph distribut call rout appropri resourc world challeng modern call center schedul creat coordin schedul util resourc distribut call center
#
# 2908.3.11 : contact center schedul problem pose challeng problem meet demand profil impli forecast incom callscontact difficult combinatori optim problem especi consid forecast probabilist minimum oneweek schedul minut granular gener typic contact center hundr agent need schedul thousand agent addit servic goal numer hard soft constraint reflect contact center oper constraint local labor rule employe prefer satisfi agent schedul specifi minimum minut granular addit specifi start time durat work shift offphon activ break need schedul furthermor advent multiskil schedul multicontact schedul significantli complic problem optim servic goal tradit method unabl keep rapidli evolv increasingli difficult schedul requir modern contact center
#
# 2908.4.34 : agent express prefer schedul treat soft constraint director type prefer rankord start time shift prefer start monday possibl start realli prefer start shift even agent express prefer set shift work work clariti restrict discuss simpl scenario agent answer phone call definit shift shift activ slightli complex consid agent partit time media type
#
# 2908.4.56 : schedul problem given forecast futur contact set employe class profil repres typic subclass agent addit constraint gener schedul consist phantom agent optim global object function
#
# 2913.3.6 : hoey describ repres transit reward model factor mdp compactli add adopt notat refer paper detail represent repres state variabl current time repres state variabl step
#
# 2913.6.2 : concept strong cyclic plan interest analog decisiontheoret plan lao origin develop framework stochast shortestpath problem stochast shortestpath problem mdp goal state object find optim polici polici reach goal state probabl polici reach goal probabl call proper polici view probabilist gener concept strong cyclic plan respect symbol lao algorithm present paper view decisiontheoret gener symbol algorithm nondeterminist plan
#
# 2916.5.16 : aaai departur object find correspond arriv determin earliest time observ pixel observ event match arriv tempor discrimin criterion exist remov process twice creat global object hypothesi gi lifetim span time arriv time departur enter gi global schedul
#
# 2916.6.2 : observ label problem given pixel valid complet global schedul determin ps visag smallest set quasistat object schedul guarante contain actual quasistat object gener ps observ
#
# 2916.6.3 : assum object visual homogen space link observ pixel base similar color andor textur conclud pixel observ object pixel observ tempor consist arriv departur salient decis time arriv depart object arriv departur time contain global schedul given complet global schedul pixel label problem independ pixel observ
#
# 2916.6.13 : object function object function map visag object function repres abstractli true state world goal label process find smallest set candid object true given model assumpt hold case physic possibl narrow singleton
#
# 2916.6.33 : algorithm maintain collect statement form visag element set ci essenti encod set candid object map visag determin qsl point algorithm start initi set true statement attempt produc smaller true statement appli qsl theorem ultim goal obtain visag true statement smallest possibl front function subset argument
#
# 2917.2.8 : highlevel specif oper effect sketch statement compris set highlevel action goal sequenc refer larg movement object friendli forc task forc arrow attack axi bull complet destruct nd red battalion overview cadet algorithm input initi set activ initi battlefield state includ unit geograph
#
# 2917.3.2 : brief human planner defin highlevel coa user interfac enabl enter compar convent coa sketch statement collect formal assert andor object includ typic order highlevel task definit coa transfer cadet proce expand highlevel specif detail planschedul oper
#
# 2925.7.5 : aaai maze problem case version observ collect determinist reward model defin follow agent declar goal locat receiv reward unit locat receiv penalti
#
# 2926.3.1 : gener multiattribut decis problem set outcom set strategi associ probabl distribut outcom aim find strategi prefer user base prefer structur outcom assum user ration prefer express util function map real outcom prefer outcom describ set attribut function domain util assum function attribut access user true util creat model base user refer estim util rest paper assum correspond strategi outcom user task choos outcom refer outcom altern
#
# 2937.3.11 : strategi quantifi formula strategi map rank adversari quantifi formula function strategi adversari quantifi formula outcom denot outcom assign defin outcom yy xi outcom
#
# 2937.3.12 : strategi quantifi formula win adversari assign outcom satisfi constraint network consid quantifi formula true exist win strategi problem formul paper focus follow restrict version qcsp relat constraint languag constraint languag defin set relat domain
#
# 2937.3.15 : find conveni use altern formul notion constraint function constraint consist set variabl call scope denot scope set function scope domain denot fun function constraint consid satisfi assign defin scope fscope fun constraint natur induc function constraint scope fun contain function tupl note assign satisfi constraint satisfi function constraint natur induc use function constraint constraint interchang paper
#
# 2941.3.1 : formal defin item graph definit given combinatori auction clear problem instanc graph vertic correspond item instanc item graph bid set item bid constitut connect set
#
# 2954.3.1 : set state plan problem hi gi observ abstractli defin term initi belief state set oper oper associ transit relat ro describ possibl transit appli set goal state
#
# 2963.3.1 : rcpspmax problem contain set activ set resourc activ start time si durat di resourc maximum capac ck execut activ requir amount rik resourc time unit execut binari preced constraint enforc minimum maximum time lag start time activ aj
#
# 2963.3.3 : goal rcpspmax problem find feasibl schedul project makespan mk maxin minim schedul problem minimum maximum time lag plan schedul find feasibl schedul rcpspmax problem nphard
#
# 2964.3.4 : robot observ properti object vicin perform action chang properti object system statement pair object adject describ properti statement assert properti object world action taken object achiev particular effect exampl statement mean cup coffe hot repres action cup coffe hot notat allow connect belief desir intent
#
# 2964.3.16 : statement statement activ user prompt question want fan activ pair object properti knowledg base object appear sentenc templat object enter user activ object activ
#
# 2964.3.18 : caus activ captur causal exampl form comput user enter object objectproperti pair enter object statement object properti sentenc form dynam select random object knowledg base
#
# 2966.3.2 : partial observ stochast game partial observ stochast game tupl hi finit set agent index finit set state repres initi state distribut finit set action agent iiai set joint action ani denot joint action oi finit set observ agent iioi set joint observ ho oni denot joint observ set markovian state transit observ probabl ps os denot probabl joint action state result transit state joint observ ri reward function agent game unfold finit infinit sequenc stage number stage call horizon game
#
# 2967.3.8 : csfr definit csfr problem defin formal quantiti set fault state pr prior probabl fault state set test action ar set repair action cost function action ar state outcom observ model action ar state
#
# 2971.4.17 : function bound mn seen creat alphabet letter assign observ unord leader goal contribut worst case goal possibl share goal given letter repres possibl goal instanc creat alphabet mn letter leader given letter indic instanc goal contribut interest case observ mn combin repres upper bound combin legal assign leader root goal instanc exampl leader assign contribut second instanc particular goal instanc goal construct alphabet assign letter leader prevent
#
# 2978.3.1 : mechan design consid system ration selfinterest agent problem choos outcom finit set possibl denot number agent agent type defin valu possibl choic privat known agent denot type vector denot type agent agent quasilinear util valu payment
#
# 2983.3.2 : knowledg represent reason follow definit assum knowledgebas use assum subset given enumer element call canon enumer realli demand constraint particular constraint satisfi impos arbitrari total order importantli order mean meant repres respect import formula conveni indic order assum formula subset conjoin formula logic equival subset
#
# 2989.2.1 : classic plan aim find sequenc action transform given initi state goal state gn conjunct list goal fluent plan success plan problem measur term conjunct achiev real world scenario agent abl satisfi subset goal
#
# 2989.3.1 : follow notat finit set fluent finit set action action consist list precondit list add delet effect set fluent describ initi state set goal conjunct defin plan problem tupl defin plan problem describ follow classic plan decis problem
#
# 2989.3.7 : problem given involv action cost andor goal util basic plan cost correspond optim problem find minimum cost plan psp util correspond optim problem find plan achiev maximum util problem psp net benefit combin plan cost psp util psp util cost gener psp net benefit formal defin decis problem psp net benefit analyz complex correspond optim problem find plan maximum net benefit focu paper
#
# 2989.3.8 : definit psp net benefit given plan problem action cost goal specif util uf posit number finit sequenc action ani start lead state net benefit uf aca exampl illustr simpl exampl student live la vega need san present aaai paper cost travel ctravel assum student arriv san automat achiev goal attend aaai util ug student want disneyland san fun havefun havefun san zoo seezoo util fun place travel cost go place given goal student find travel plan give costutil tradeoff exampl plan travel travel travel achiev goal ignor
#
# 2994.5.19 : find goal consid goal locat locat person typic spend extend period time extract signific locat detect place gp signal lost disadvantag approach detect indoor goal overcom problem store edg graph person stay edg estim flat em model loss gp signal transit build mode model detect indoor outdoor goal signific edg detect cluster combin edg connect close
#
# 2997.3.1 : discuss formal depend pattern part whole conceptu draw common categori knowledg represent concept character attribut properti slot framebas represent role descript logic system role filler restrict constrain sortal rang exampl concept liver reason filler role hasloc hepat concept defin conceptu relat target concept follow distinct role statu mandatori role concept requir fill filler type case hasloc liver defin concept hepat allow infer concret hepat concret liver locat
#
# 3002.3.1 : filter problem notat number user total number item databas matrix user rate item sui rate given user item rate typic cardin scale valu
#
# 3004.2.1 : cpnet formal compactli express condit prefer multivari problem involv statement form valu variabl assign set variabl interpret given prefer equal assign variabl sux prefer sux sux outcom set statement gener prefer relat complet tupl consist correspond induc prefer relat acycl partial order
#
# 3004.2.4 : cpnet quit restrict kind prefer statement repres ceteri paribu statement base express natur kind prefer weak agent want express stronger statement prefer irrespect valu variabl variabl import variabl exampl repres valu copyright american associ artifici intellig right reserv
#
# 3004.2.6 : paper develop formal similar line cpnet richer languag prefer statement express stronger condit prefer statement usual cpnet ceteri paribu statement allow local partial order prefer languag consist statement form repres assign assign tuxw prefer tux given prefer irrespect valu
#
# 3004.5.3 : fix condit prefer theori consid outcom variabl pair valu valid exist statement defin relat transit closur set pair valid local consist irreflex
#
# 3004.7.3 : despit substanti express languag cpnet quit restrict natur way augment languag allow compact represent kind prefer exampl allow statement form assign set variabl singl variabl allow statement form mean condit prefer assign variabl languag extend allow represent indiffer valu partial tupl
#
# 3006.2.1 : biggest limit classic plan assumpt determin classic planner assum know exact outcom action given plan initi state world evolv singl fulli predict path
#
# 3013.4.23 : goal assumpt plan consid reachabl goal goal domain hs xi set state problem pair hd gi reach finit number plan execut step problem suffici consid acycl plan branch base sens observ definit plan domain hs xi nonempti set pair hof tripl hof plan
#
# 3013.4.37 : definit plan strong solut problem hd gi iff trace goal trace tr reach exampl consid domain plan previou exampl plan strong solut problem reach fill printer statu tr assumpt domain behaviour simplifi problem narrow paper consid assumpt restrict initi state domain definit assumpt domain hs xi set state intend restrict possibl initi state
#
# 3034.5.3 : subsequ state cpgcoupl system simpli denot formul mdp state space action space cpgcoupl system assum cost function given map ps repres probabl system chang current state state action given
#
# 3038.3.24 : given state defin agent local state state oi conveni denot associ interpret system ip set run satisfi form state assign assign satisfi natur number assign assign satisfi
#
# 3040.3.1 : discuss paper focus constraint satisfact problem result algorithm appli satisfi problem proposit satisfi satisfi concept descript logic complet abstract underli constraint languag simpli assum monoton satisfi properti solut set constraint solut subset
#
# 3042.3.8 : qk consist statement node connect direct arc node arc type base mean purpos short descript statement node relat arc refer provid complet discuss
#
# 3042.3.9 : statement node contain individu piec data qk statement node contain simpl sentenc number combin sentenc statement node categor state event goal style concept node state node describ worldstat assum remain true explicitli chang event node describ chang state intent
#
# 3043.3.1 : pomdp defin set state set action set observ transit function denot probabl pr transit state action taken state observ function denot probabl prz make observ perform reward function denot immedi reward associ state action assum discret state action observ set focu discount infinit horizon pomdp discount factor consid fsc pomdp assum initi belief state denot initi distribut state probabl initi state
